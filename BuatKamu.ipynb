# %% [markdown]
# <a href="https://colab.research.google.com/github/awzipaa/anniv/blob/main/BuatKamu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

project = "/content/anniversary_web"
os.makedirs(project, exist_ok=True)
os.makedirs(project + "/photos", exist_ok=True)
os.makedirs(project + "/music", exist_ok=True)
os.makedirs(project + "/video", exist_ok=True)

print("Folder project berhasil dibuat!")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

project = "/content/drive/MyDrive/anniversary_web"

os.makedirs(project, exist_ok=True)
os.makedirs(project + "/photos", exist_ok=True)
os.makedirs(project + "/music", exist_ok=True)
os.makedirs(project + "/video", exist_ok=True)

print("Folder di Drive berhasil dibuat!")
# Out:
# Folder di Drive berhasil dibuat!

# %%
import os

print("Foto:", os.listdir(project + "/photos"))
print("Musik:", os.listdir(project + "/music"))
print("Video:", os.listdir(project + "/video"))
# Out:
# Foto: ['WhatsApp Image 2026-06-26 at 13.55.05 (1).jpeg', 'foto2.jpeg', 'foto3.jpeg', 'WhatsApp Image 2026-06-26 at 13.55.06.jpeg', 'foto 1.jpeg']
# Musik: ['lagu.mp4']
# Video: ['WhatsApp Video 2026-06-26 at 13.55.50.mp4', 'WhatsApp Video 2026-06-26 at 13.55.50 (1).mp4', 'video.mp4', 'WhatsApp Video 2026-06-26 at 13.55.51.mp4']

# %%
html_code = """
<!DOCTYPE html>
<html lang="id">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Happy Anniversary</title>
  <link rel="stylesheet" href="style.css">
</head>
<body>

<video id="music" autoplay loop style="display:none;">
    <source src="music/lagu.mp4" type="video/mp4">
</video>

<section id="cover" class="cover">
  <div class="card">
    <p class="small">A little surprise for you</p>
    <h1>Happy Anniversary ❤️</h1>
    <p>Untuk orang paling spesial di hidupku.</p>
    <button onclick="startSurprise()">Klik Aku</button>
  </div>
</section>

<section id="main" class="hidden">
  <div class="hero">
    <h1>Untuk Kamu, Sayang ❤️</h1>
    <p id="typing"></p>
  </div>

<div class="counter">
  <h2>Kita sudah bersama selama</h2>
  <div id="daysTogether">0 hari</div>
</div>

  <div class="polaroid-gallery">
    <img src="photos/foto 1.jpeg">
    <img src="photos/foto2.jpeg">
    <img src="photos/foto3.jpeg">
  </div>

  <div class="timeline">
    <h2>Our Little Timeline</h2>
    <div class="timeline-item">🌸 Pertama kali kenal</div>
    <div class="timeline-item">💬 Mulai sering ngobrol</div>
    <div class="timeline-item">❤️ Mulai saling sayang</div>
    <div class="timeline-item">✨ Hari ini masih saling memilih</div>
  </div>

  <div class="letter">
    <h2>Surat Untuk Kamu</h2>
    <p>
      Terima kasih sudah hadir, bertahan, dan tetap menjadi bagian indah dalam hidupku.
      Aku tahu perjalanan kita tidak selalu mudah, tapi aku senang karena kita masih di sini.
      Semoga ke depannya kita bisa terus saling menjaga, saling memahami, dan membuat lebih banyak kenangan kecil yang berarti.
    </p>
  </div>

  <div class="video-box">
    <h2>Our Memory</h2>
    <video controls>
      <source src="video/video.mp4" type="video/mp4">
    </video>
  </div>

  <div class="ending">
    <h2>Will you keep making memories with me?</h2>
    <button onclick="yesClicked()">YES ❤️</button>
    <p id="finalText"></p>
  </div>
</section>

<script src="script.js"></script>
</body>
</html>
"""

with open(project + "/index.html", "w") as f:
    f.write(html_code)

# %%
css_code = """
* {
  box-sizing: border-box;
}

body {
  margin: 0;
  font-family: 'Segoe UI', sans-serif;
  background: linear-gradient(135deg, #ffe1ec, #fff7fb);
  color: #5c1a33;
  text-align: center;
  overflow-x: hidden;
}

.hidden {
  display: none;
}

.cover {
  min-height: 100vh;
  display: flex;
  justify-content: center;
  align-items: center;
  background: radial-gradient(circle, #fff 0%, #ffb6d5 45%, #ff7eb3 100%);
  padding: 20px;
}

.card {
  background: rgba(255,255,255,0.85);
  padding: 45px 30px;
  border-radius: 35px;
  max-width: 430px;
  width: 100%;
  box-shadow: 0 25px 60px rgba(255, 79, 147, 0.35);
  animation: pop 1.2s ease;
}

.card h1 {
  font-size: 38px;
  margin: 10px 0;
}

.small {
  letter-spacing: 2px;
  font-size: 13px;
  text-transform: uppercase;
}

button {
  background: linear-gradient(135deg, #ff4f93, #ff7eb3);
  color: white;
  border: none;
  padding: 14px 32px;
  border-radius: 999px;
  font-size: 18px;
  cursor: pointer;
  box-shadow: 0 10px 25px rgba(255, 79, 147, 0.35);
  transition: 0.3s;
}

button:hover {
  transform: scale(1.07);
}

.hero {
  min-height: 80vh;
  padding: 80px 20px 40px;
  display: flex;
  justify-content: center;
  align-items: center;
  flex-direction: column;
}

.hero h1 {
  font-size: 42px;
}

#typing {
  max-width: 700px;
  font-size: 22px;
  line-height: 1.7;
}

.counter, .timeline, .letter, .video-box, .ending {
  background: rgba(255,255,255,0.9);
  margin: 35px auto;
  padding: 28px;
  max-width: 780px;
  width: 90%;
  border-radius: 28px;
  box-shadow: 0 15px 35px rgba(0,0,0,0.08);
}

#daysTogether {
  font-size: 35px;
  font-weight: bold;
  color: #ff4f93;
}

.polaroid-gallery {
  display: flex;
  justify-content: center;
  gap: 22px;
  flex-wrap: wrap;
  padding: 30px 15px;
}

.polaroid-gallery img {
  width: 230px;
  height: 290px;
  object-fit: cover;
  background: white;
  padding: 12px 12px 40px;
  border-radius: 10px;
  box-shadow: 0 15px 35px rgba(0,0,0,0.18);
  transform: rotate(-3deg);
  transition: 0.3s;
}

.polaroid-gallery img:nth-child(2) {
  transform: rotate(4deg);
}

.polaroid-gallery img:hover {
  transform: scale(1.06) rotate(0deg);
}

.timeline-item {
  margin: 15px auto;
  padding: 15px;
  max-width: 520px;
  border-radius: 18px;
  background: #fff0f6;
  font-size: 18px;
}

.letter p {
  font-size: 18px;
  line-height: 1.9;
}

video {
  width: 100%;
  max-width: 680px;
  border-radius: 25px;
}

.float {
  position: fixed;
  top: -30px;
  z-index: 999;
  pointer-events: none;
  animation: fall linear forwards;
}

@keyframes fall {
  to {
    transform: translateY(110vh) rotate(360deg);
    opacity: 0;
  }
}

@keyframes pop {
  from {
    opacity: 0;
    transform: scale(0.8);
  }
  to {
    opacity: 1;
    transform: scale(1);
  }
}

@media (max-width: 600px) {
  .card h1, .hero h1 {
    font-size: 30px;
  }

  #typing {
    font-size: 18px;
  }

  .polaroid-gallery img {
    width: 180px;
    height: 240px;
  }
}
"""

with open(project + "/style.css", "w") as f:
    f.write(css_code)

# %%
js_code = """
const startDate = new Date("2025-06-26");

function startSurprise() {
  document.getElementById("cover").classList.add("hidden");
  document.getElementById("main").classList.remove("hidden");

  const music = document.getElementById("music");
  music.play();

  typeText();
  updateDays();
  setInterval(createFloating, 350);
}

function typeText() {
  const text = "Hari ini bukan cuma tentang tanggal, tapi tentang semua hal kecil yang sudah kita lewati bersama. Terima kasih sudah menjadi orang yang selalu aku syukuri.";
  const target = document.getElementById("typing");
  let i = 0;

  function typing() {
    if (i < text.length) {
      target.innerHTML += text.charAt(i);
      i++;
      setTimeout(typing, 45);
    }
  }

  typing();
}

function updateDays() {
  const now = new Date();
  const diff = now - startDate;
  const days = Math.floor(diff / (1000 * 60 * 60 * 24));
  document.getElementById("daysTogether").innerHTML = days + " hari";
}

function createFloating() {
  const item = document.createElement("div");
  item.className = "float";
  item.innerHTML = ["❤️", "💖", "🌸", "✨", "🥺"][Math.floor(Math.random() * 5)];
  item.style.left = Math.random() * 100 + "vw";
  item.style.fontSize = Math.random() * 18 + 18 + "px";
  item.style.animationDuration = Math.random() * 4 + 4 + "s";

  document.body.appendChild(item);

  setTimeout(() => {
    item.remove();
  }, 8000);
}

function yesClicked() {
  document.getElementById("finalText").innerHTML = "Yeayyy, aku sayang kamu. Terima kasih sudah tetap di sini ❤️";

  for (let i = 0; i < 120; i++) {
    setTimeout(createFloating, i * 20);
  }
}
"""

with open(project + "/script.js", "w") as f:
    f.write(js_code)

# %%
project = "/content/drive/MyDrive/anniversary_web"

js_code = """
function startSurprise() {
  alert("Tombol berhasil diklik!");

  document.getElementById("cover").style.display = "none";
  document.getElementById("main").style.display = "block";

  const music = document.getElementById("music");
  music.play().catch(function(error) {
    alert("Musik belum bisa diputar. Cek nama file lagu.mp3 di folder music.");
  });

  setInterval(createFloating, 500);
}

function createFloating() {
  const item = document.createElement("div");
  item.className = "float";
  item.innerHTML = "❤️";
  item.style.left = Math.random() * 100 + "vw";
  item.style.fontSize = "24px";
  item.style.animationDuration = "5s";
  document.body.appendChild(item);

  setTimeout(function() {
    item.remove();
  }, 6000);
}

function yesClicked() {
  alert("Yeayyy ❤️");
}
"""

with open(project + "/script.js", "w") as f:
    f.write(js_code)

print("script.js sudah diperbaiki!")
# Out:
# script.js sudah diperbaiki!

# %%
# %cd /content/drive/MyDrive/anniversary_web
# !python -m http.server 8000
# Out:
# /content/drive/MyDrive/anniversary_web
# Serving HTTP on 0.0.0.0 port 8000 (http://0.0.0.0:8000/) ...
# 127.0.0.1 - - [26/Jun/2026 07:27:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:54] "GET /style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:54] "GET /photos/foto2.jpeg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:54] "GET /music/lagu.mp4 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:54] "GET /video/video.mp4 HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:55] "GET /script.js HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:55] "GET /photos/foto%201.jpeg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:55] "GET /photos/foto3.jpeg HTTP/1.1" 200 -
# 127.0.0.1 - - [26/Jun/2026 07:27:59] code 404, message File not found
# 127.0.0.1 - - [26/Jun/2026 07:27:59] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://8000-m-s-kkb-use1c1-2tk51cxikcp3o-c.us-east1-1.prod.colab.dev
